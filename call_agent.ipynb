# %%
import requests

# %%
base_url = "http://localhost:8000"
post_data = {"message": "Что такое ИСЖ?"}

# %%
response = requests.post(f"{base_url}/chat", json=post_data)
print(response.status_code)
print(response.json())
# Out:
# 200
# ...
